# %% [markdown]
# ## 영등포구 소재 지하철역

# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('data/영등포소재 지하철역2.csv')
df
# Out:
#        이름                             주소         위도          경도
# 0    영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659
# 1    신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719
# 2     당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731
# 3    여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485
# 4  영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=14)  # Center position
for i in df.index:
    folium.Marker(
        location=[df.위도[i], df.경도[i]],       
        tooltip=df.이름[i],
        popup=folium.Popup(df.주소[i], max_width=200)
    ).add_to(map)

title_html = '<h3 align="center" style="font-size:20px">영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fca7ac540cbc29bb39028824fe81257b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align=&quot;center&quot; style=&quot;font-size:20px&quot;&gt;영등포소재 주요 지하철역&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fca7ac540cbc29bb39028824fe81257b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fca7ac540cbc29bb39028824fe81257b = L.map(
#                 &quot;map_fca7ac540cbc29bb39028824fe81257b&quot;,
#                 {
#                     center: [37.52120913312664, 126.9030439466804],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_035f897384036c77c73d6cc729843020 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fca7ac540cbc29bb39028824fe81257b);
#
#
#             var marker_e3b6675a96acd316d6252eb4509ce27e = L.marker(
#                 [37.5164625580995, 126.906658750671],
#                 {}
#             ).addTo(map_fca7ac540cbc29bb39028824fe81257b);
#
#
#         var popup_81dc82a9f78c46a9bf4e6be2f77ead77 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_3833beec163cb7be47a5a3d84f10df67 = $(`&lt;div id=&quot;html_3833beec163cb7be47a5a3d84f10df67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 경인로 지하843 (영등포동3가)&lt;/div&gt;`)[0];
#                 popup_81dc82a9f78c46a9bf4e6be2f77ead77.setContent(html_3833beec163cb7be47a5a3d84f10df67);
#
#
#
#         marker_e3b6675a96acd316d6252eb4509ce27e.bindPopup(popup_81dc82a9f78c46a9bf4e6be2f77ead77)
#         ;
#
#
#
#
#             marker_e3b6675a96acd316d6252eb4509ce27e.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1700a34d1822f8218088071e9e0fb281 = L.marker(
#                 [37.5070842748567, 126.884718686628],
#                 {}
#             ).addTo(map_fca7ac540cbc29bb39028824fe81257b);
#
#
#         var popup_e2ce3ffd3c806a939c0de8e3ea01c61e = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_531853bc51cb0b6b990af64100833fad = $(`&lt;div id=&quot;html_531853bc51cb0b6b990af64100833fad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 구로구 경인로 625 (신도림동)&lt;/div&gt;`)[0];
#                 popup_e2ce3ffd3c806a939c0de8e3ea01c61e.setContent(html_531853bc51cb0b6b990af64100833fad);
#
#
#
#         marker_1700a34d1822f8218088071e9e0fb281.bindPopup(popup_e2ce3ffd3c806a939c0de8e3ea01c61e)
#         ;
#
#
#
#
#             marker_1700a34d1822f8218088071e9e0fb281.bindTooltip(
#                 `&lt;div&gt;
#                      신도림역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2d49d4ce1c17a6e3eddfe2f2388a497d = L.marker(
#                 [37.534956866618, 126.90273071003],
#                 {}
#             ).addTo(map_fca7ac540cbc29bb39028824fe81257b);
#
#
#         var popup_8cdac1cdd775d9112a725d0fcb3ff8be = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_a3707265401a0720d3e43f643732e9ba = $(`&lt;div id=&quot;html_a3707265401a0720d3e43f643732e9ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 당산로 229 (당산동6가)&lt;/div&gt;`)[0];
#                 popup_8cdac1cdd775d9112a725d0fcb3ff8be.setContent(html_a3707265401a0720d3e43f643732e9ba);
#
#
#
#         marker_2d49d4ce1c17a6e3eddfe2f2388a497d.bindPopup(popup_8cdac1cdd775d9112a725d0fcb3ff8be)
#         ;
#
#
#
#
#             marker_2d49d4ce1c17a6e3eddfe2f2388a497d.bindTooltip(
#                 `&lt;div&gt;
#                      당산역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_450eecc5c91f046c7ccf6534f8261572 = L.marker(
#                 [37.5218423045786, 126.924484687694],
#                 {}
#             ).addTo(map_fca7ac540cbc29bb39028824fe81257b);
#
#
#         var popup_d6ae3d4f9a04f2a70815084f7787c926 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_c3e82f6f20d21cf003a5dd3135aae56a = $(`&lt;div id=&quot;html_c3e82f6f20d21cf003a5dd3135aae56a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 여의나루로 지하40 (여의도동)&lt;/div&gt;`)[0];
#                 popup_d6ae3d4f9a04f2a70815084f7787c926.setContent(html_c3e82f6f20d21cf003a5dd3135aae56a);
#
#
#
#         marker_450eecc5c91f046c7ccf6534f8261572.bindPopup(popup_d6ae3d4f9a04f2a70815084f7787c926)
#         ;
#
#
#
#
#             marker_450eecc5c91f046c7ccf6534f8261572.bindTooltip(

# %%
df['color'] = ['red', 'blue', 'green', 'violet', 'orange']
df
# Out:
#        이름                             주소         위도          경도   color
# 0    영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659     red
# 1    신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719    blue
# 2     당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731   green
# 3    여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485  violet
# 4  영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627  orange

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=14)  # Center position
for i in df.index:
    folium.Circle(
        location=[df.위도[i], df.경도[i]],       
        tooltip=df.이름[i],
        popup=folium.Popup(df.주소[i], max_width=200),
        radius=100, color=df.color[i], fill=True
    ).add_to(map)
    folium.map.Marker(
        location=[df.위도[i], df.경도[i]], 
        icon = folium.DivIcon(icon_size=(80,20), icon_anchor=(20,0),
                    html=f'<span style="font-size: 10pt">{df.이름[i]}</span>')
    ).add_to(map)

folium.Marker(
    location=[df.위도.mean(), df.경도.mean()],
    icon=folium.CustomIcon('data/pushpin.png', icon_size=(30,30))
).add_to(map)

title_html = '<h3 align="center" style="font-size:20px">영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\works\DataAnalysis-2023.09\04.지도시각화\04.영등포소재지하철역.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     folium.Circle(
#       <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>         location=[df.위도[i], df.경도[i]],
#       <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>         tooltip=df.이름[i],
#       <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>         popup=folium.Popup(df.주소[i], max_width=200),
#       <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a>         radius=100, color=df.color[i], fill=True
#       <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>     ).add_to(map)
#       <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a>     folium.map.Marker(
#      <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a>         location=[df.위도[i], df.경도[i]],
#      <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a>         icon = folium.DivIcon(icon_size=(80,20), icon_anchor=(20,0),
#      <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=11'>12</a>                     html=f'<span style="font-size: 10pt">{df.이름[i]}</span>')
#      <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a>     ).add_to(map)
#      <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a> folium.Marker(
#      <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a>     location=[df.위도.mean(), df.경도.mean()],
# ---> <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a>     icon=folium.CustomIcon('data/pushpin.png', icon_size=(30,30))
#      <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> ).add_to(map)
#      <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=19'>20</a> title_html = '<h3 align="center" style="font-size:20px">영등포소재 주요 지하철역</h3>'
#      <a href='vscode-notebook-cell:/d%3A/works/DataAnalysis-2023.09/04.%EC%A7%80%EB%8F%84%EC%8B%9C%EA%B0%81%ED%99%94/04.%EC%98%81%EB%93%B1%ED%8F%AC%EC%86%8C%EC%9E%AC%EC%A7%80%ED%95%98%EC%B2%A0%EC%97%AD.ipynb#W5sZmlsZQ%3D%3D?line=20'>21</a> map.get_root().html.add_child(folium.Element(title_html))
#
# File c:\Users\human\anaconda3\Lib\site-packages\folium\features.py:1838, in CustomIcon.__init__(self, icon_image, icon_size, icon_anchor, shadow_image, shadow_size, shadow_anchor, popup_anchor)
#    1835 super(Icon, self).__init__()
#    1836 self._name = "CustomIcon"
#    1837 self.options = parse_options(
# -> 1838     icon_url=image_to_url(icon_image),
#    1839     icon_size=icon_size,
#    1840     icon_anchor=icon_anchor,
#    1841     shadow_url=shadow_image and image_to_url(shadow_image),
#    1842     shadow_size=shadow_size,
#    1843     shadow_anchor=shadow_anchor,
#    1844     popup_anchor=popup_anchor,
#    1845 )
#
# File c:\Users\human\anaconda3\Lib\site-packages\folium\utilities.py:148, in image_to_url(image, colormap, origin)
#     146 if isinstance(image, str) and not _is_url(image):
#     147     fileformat = os.path.splitext(image)[-1][1:]
# --> 148     with open(image, "rb") as f:
#     149         img = f.read()
#     150     b64encoded = base64.b64encode(img).decode("utf-8")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/pushpin.png'
