# %% [markdown]
# ### 2.7 데이터프레임 합성(merge)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - merge

# %%
df1 = pd.DataFrame({
    '고객번호': [1001, 1002, 1003, 1004, 1005, 1006, 1007],
    '이름': ['둘리', '도우너', '또치', '길동', '희동', '마이콜', '영희']
}, columns=['고객번호', '이름'])
df1
# Out:
#    고객번호   이름
# 0  1001   둘리
# 1  1002  도우너
# 2  1003   또치
# 3  1004   길동
# 4  1005   희동
# 5  1006  마이콜
# 6  1007   영희

# %%
df2 = pd.DataFrame({
    '고객번호': [1001, 1001, 1005, 1006, 1008, 1001],
    '금액': [10000, 20000, 15000, 5000, 100000, 30000]
}, columns=['고객번호', '금액'])
df2
# Out:
#    고객번호      금액
# 0  1001   10000
# 1  1001   20000
# 2  1005   15000
# 3  1006    5000
# 4  1008  100000
# 5  1001   30000

# %%
# Inner join - 컬럼명이 같은 열(고객번호)을 기준으로, 공통 데이터만 합성
pd.merge(df1, df2)
# Out:
#    고객번호   이름     금액
# 0  1001   둘리  10000
# 1  1001   둘리  20000
# 2  1001   둘리  30000
# 3  1005   희동  15000
# 4  1006  마이콜   5000

# %%
# Left outer join
pd.merge(df1, df2, how='left')
# Out:
#    고객번호   이름       금액
# 0  1001   둘리  10000.0
# 1  1001   둘리  20000.0
# 2  1001   둘리  30000.0
# 3  1002  도우너      NaN
# 4  1003   또치      NaN
# 5  1004   길동      NaN
# 6  1005   희동  15000.0
# 7  1006  마이콜   5000.0
# 8  1007   영희      NaN

# %%
# Right outer join
pd.merge(df1, df2, how='right')
# Out:
#    고객번호   이름      금액
# 0  1001   둘리   10000
# 1  1001   둘리   20000
# 2  1005   희동   15000
# 3  1006  마이콜    5000
# 4  1008  NaN  100000
# 5  1001   둘리   30000

# %%
# Full outer join
pd.merge(df1, df2, how='outer')
# Out:
#    고객번호   이름        금액
# 0  1001   둘리   10000.0
# 1  1001   둘리   20000.0
# 2  1001   둘리   30000.0
# 3  1002  도우너       NaN
# 4  1003   또치       NaN
# 5  1004   길동       NaN
# 6  1005   희동   15000.0
# 7  1006  마이콜    5000.0
# 8  1007   영희       NaN
# 9  1008  NaN  100000.0

# %% [markdown]
#  - join() method

# %%
# index로 join
df1.set_index('고객번호', inplace=True)
df2.set_index('고객번호', inplace=True)

# %%
df1.join(df2)
# Out:
#        이름       금액
# 고객번호
# 1001   둘리  10000.0
# 1001   둘리  20000.0
# 1001   둘리  30000.0
# 1002  도우너      NaN
# 1003   또치      NaN
# 1004   길동      NaN
# 1005   희동  15000.0
# 1006  마이콜   5000.0
# 1007   영희      NaN

# %%
# Inner join
pd.merge(df1, df2, left_index=True, right_index=True)
# Out:
#        이름     금액
# 고객번호
# 1001   둘리  10000
# 1001   둘리  20000
# 1001   둘리  30000
# 1005   희동  15000
# 1006  마이콜   5000

# %% [markdown]
# - 연습문제 4.6.1

# %%
df3 = pd.DataFrame(np.random.randint(100, 110, size=(5,5)), columns=list('ABCDE'))
df3
# Out:
#      A    B    C    D    E
# 0  109  109  104  103  109
# 1  108  104  104  107  106
# 2  108  101  100  108  105
# 3  102  107  105  106  106
# 4  100  100  106  106  105

# %%
df4 = pd.DataFrame(np.random.randint(100, 110, size=(5,5)), columns=list('ABXYZ'))
df4
# Out:
#      A    B    X    Y    Z
# 0  107  102  108  108  101
# 1  103  109  106  102  101
# 2  104  107  101  107  106
# 3  100  107  103  107  107
# 4  100  102  104  106  101

# %%
# A 열 기준
pd.merge(df3, df4, on='A')
# Out:
#      A  B_x    C    D    E  B_y    X    Y    Z
# 0  100  100  106  106  105  107  103  107  107
# 1  100  100  106  106  105  102  104  106  101

# %%
# B 열 기준
pd.merge(df3, df4, on='B')
# Out:
#    A_x    B    C    D    E  A_y    X    Y    Z
# 0  109  109  104  103  109  103  106  102  101
# 1  102  107  105  106  106  104  101  107  106
# 2  102  107  105  106  106  100  103  107  107

# %%
# A열과 B열 기준
pd.merge(df3, df4, on=['A','B'])
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, X, Y, Z]
# Index: []

# %%
# C열 == X열 기준
pd.merge(df3, df4, left_on='C', right_on='X')
# Out:
#    A_x  B_x    C    D    E  A_y  B_y    X    Y    Z
# 0  109  109  104  103  109  100  102  104  106  101
# 1  108  104  104  107  106  100  102  104  106  101
# 2  100  100  106  106  105  103  109  106  102  101

# %% [markdown]
# - concat

# %%
df5 = pd.DataFrame(
    np.arange(6).reshape(3, 2),
    index=['a', 'b', 'c'],
    columns=['데이터1', '데이터2'])
df5
# Out:
#    데이터1  데이터2
# a     0     1
# b     2     3
# c     4     5

# %%
df6 = pd.DataFrame(
    5 + np.arange(4).reshape(2, 2),
    index=['a', 'c'],
    columns=['데이터3', '데이터4'])
df6
# Out:
#    데이터3  데이터4
# a     5     6
# c     7     8

# %%
pd.concat([df5,df5])        # Vertical stack
# Out:
#    데이터1  데이터2
# a     0     1
# b     2     3
# c     4     5
# a     0     1
# b     2     3
# c     4     5

# %%
pd.concat([df5, df6], axis=1)       # Horizontal stack
# Out:
#    데이터1  데이터2  데이터3  데이터4
# a     0     1   5.0   6.0
# b     2     3   NaN   NaN
# c     4     5   7.0   8.0

# %% [markdown]
# - 연습문제 4.6.2

# %%
df7 = pd.DataFrame(np.random.randint(500, 1000, size=(6,2)) * 1000,
                   columns=['매출', '비용'], index='1월 2월 3월 4월 5월 6월'.split())
df7['이익'] = df7['매출'] - df7['비용']
df7
# Out:
#         매출      비용      이익
# 1월  931000  689000  242000
# 2월  922000  951000  -29000
# 3월  621000  820000 -199000
# 4월  749000  813000  -64000
# 5월  988000  842000  146000
# 6월  678000  523000  155000

# %%
df8 = pd.DataFrame(np.random.randint(500, 1000, size=(6,2)) * 1000,
                   columns=['매출', '비용'], index='7월 8월 9월 10월 11월 12월'.split())
df8['이익'] = df8['매출'] - df8['비용']
df8
# Out:
#          매출      비용      이익
# 7월   704000  547000  157000
# 8월   993000  730000  263000
# 9월   573000  710000 -137000
# 10월  619000  532000   87000
# 11월  893000  576000  317000
# 12월  816000  631000  185000

# %%
pd.concat([df7,df8])
# Out:
#          매출      비용      이익
# 1월   931000  689000  242000
# 2월   922000  951000  -29000
# 3월   621000  820000 -199000
# 4월   749000  813000  -64000
# 5월   988000  842000  146000
# 6월   678000  523000  155000
# 7월   704000  547000  157000
# 8월   993000  730000  263000
# 9월   573000  710000 -137000
# 10월  619000  532000   87000
# 11월  893000  576000  317000
# 12월  816000  631000  185000

# %%
df9.loc['합계'] = df9.sum(axis=0)
df9.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\WorkspaceSJH\02.DataAnalysis\02.Pandas\07.합성.ipynb 셀 30 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/WorkspaceSJH/02.DataAnalysis/02.Pandas/07.%ED%95%A9%EC%84%B1.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> df9.loc['합계'] = df9.sum(axis=0)
#       <a href='vscode-notebook-cell:/d%3A/WorkspaceSJH/02.DataAnalysis/02.Pandas/07.%ED%95%A9%EC%84%B1.ipynb#X44sZmlsZQ%3D%3D?line=1'>2</a> df9.tail()
#
# NameError: name 'df9' is not defined
